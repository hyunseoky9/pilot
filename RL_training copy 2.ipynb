# %% [markdown]
# # Choose reference portfolio return

# %%
from pprdyn1 import *
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import pickle
import numpy as np
import pandas as pd
from performance_eval import avgperformance

config = {'policytype': 0, 'num_episodes': 1000}
settings = {'settingID': 18, 'for_RL': 0}
env = pprdyn1(settings)
summary = avgperformance(env, config, collect_data=True)
# average return using value iteraiton policy for each timestep.
summary['portfolioreturn'].mean(axis=0)
# Recommendation: average of the average returns is about *1.85*. Use this value as R_ref.
# Out:
# policy type: value iteration
# Episode 1000 done
# MC log_negV = -6.590662
# Average reward over 1000 episodes: -9.3339, certrainty equivalent: 1.3673
# array([2.22334062, 2.01649829, 1.85343344, 1.77733091, 1.75704407,
#        1.76121069, 1.78069268, 1.76588749, 1.75929858, 1.75398583])

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

if __name__ == "__main__":
    paramid = 5 # test id = 4
    iteration_num = 40
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 0, seed: 951408
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.69
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.69
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.72
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.73
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.74
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.78
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.96
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# best Policy network found at episode 23000
# Training completed.
# Tuneset 1, Iteration 0: [1.95791809 1.94666054 1.9456827  1.94178761 1.94121687 1.93979687
#  1.93613921 1.93530984 1.93378089 1.93364305 1.93264064 1.93068581
#  1.92721951 1.92702326 1.92609578 1.92559409 1.9245335  1.92126741
#  1.92038997 1.91890955 1.91681515 1.9147854  1.91318811 1.90904062
#  1.90778833 1.90253231 1.90243055 1.89860484 1.89084437 1.88844795
#  1.88722481 1.88295862 1.87992129 1.87761852 1.87298234 1.8725345
#  1.86663618 1.86583735 1.86554949 1.86086473 1.85990597 1.85988819
#  1.857044   1.85543541 1.85503991 1.85341149 1.85229361 1.8491025
#  1.84258397 1.83458877 1.83401202 1.83389529 1.82571895 1.81560071
#  1.77859609 1.7418126  1.73110788 1.71721387 1.69011221 1.68771166]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 1, seed: 994461
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.69
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.71
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.73
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.79
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.79
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# best Policy network found at episode 30000
# Training completed.
# Tuneset 1, Iteration 1: [1.94508224 1.94211074 1.93839792 1.93314486 1.93148145 1.92903259
#  1.91869374 1.915579   1.91477183 1.9104974  1.90855817 1.90580623
#  1.90576774 1.90488611 1.90338737 1.90303549 1.90196886 1.90032955
#  1.90006605 1.88969619 1.88969229 1.88865407 1.88428946 1.88314224
#  1.87796817 1.87715023 1.87527566 1.87446452 1.87418049 1.87111664
#  1.87080284 1.86692191 1.85964996 1.8588871  1.85867713 1.85749621
#  1.85356992 1.85309014 1.85245051 1.85186984 1.85155567 1.84967029
#  1.84490974 1.84315291 1.84218795 1.84215852 1.84094868 1.83732646
#  1.83627038 1.83108072 1.82979135 1.82972882 1.82578488 1.81473722
#  1.80821114 1.79126921 1.78584633 1.73482918 1.71485735 1.69120663]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 2, seed: 753771
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.69
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.73
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.79
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# best Policy network found at episode 6500
# Training completed.
# Tuneset 1, Iteration 2: [1.85772277 1.85443486 1.85353753 1.85231458 1.84730646 1.84662398
#  1.84340194 1.84312476 1.84286724 1.84087426 1.84017365 1.83855034
#  1.83744329 1.83649628 1.8356272  1.8349064  1.83476994 1.83454024
#  1.83427352 1.83296384 1.83215601 1.83189682 1.83184972 1.83177998
#  1.83172674 1.8316325  1.82879214 1.82858652 1.82839312 1.8283926
#  1.82780883 1.82710877 1.82681854 1.8266678  1.82626103 1.82625534
#  1.82619066 1.82559394 1.82502014 1.82402435 1.82314331 1.82236656
#  1.8208839  1.82080844 1.81902553 1.81900159 1.81614595 1.81599975
#  1.81483774 1.81357486 1.81353498 1.81146138 1.80972173 1.80746134
#  1.80585702 1.79728724 1.78952875 1.73264597 1.70078943 1.69465084]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 3, seed: 316452
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.72
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.71
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.74
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.77
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.79
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# best Policy network found at episode 18500
# Training completed.
# Tuneset 1, Iteration 3: [1.86935862 1.86315669 1.85673841 1.8547337  1.85271125 1.85257296
#  1.85242469 1.85136545 1.85056253 1.85007123 1.84828414 1.84759846
#  1.84701675 1.84682531 1.84572103 1.8454167  1.84493366 1.84334773
#  1.84319642 1.84220883 1.84068531 1.83865337 1.83685511 1.8368215
#  1.8366689  1.83645778 1.83586081 1.83478044 1.83409462 1.8334393
#  1.83230795 1.83182404 1.83150389 1.83115906 1.83007506 1.82968116
#  1.82887771 1.82724589 1.82629708 1.82617734 1.82349352 1.8218055
#  1.8213104  1.82067696 1.81958943 1.81949452 1.81809232 1.81685664
#  1.81632851 1.80955062 1.80818415 1.80624009 1.80372502 1.80364336
#  1.79284428 1.7730959  1.73849574 1.71534177 1.70997617 1.69771668]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 4, seed: 139600
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.73
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.73
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.75
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.75
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.79
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 16500
# ...
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.92
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.93
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.94
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.95
# -----------------------------------
# best Policy network found at episode 18500
# Training completed.
# Tuneset 1, Iteration 8: [1.95337099 1.95199008 1.94962901 1.94530183 1.94505288 1.94444539
#  1.94195023 1.9417919  1.94152983 1.93962116 1.93961448 1.93930223
#  1.9385187  1.93494775 1.93474815 1.93246818 1.9318255  1.93092889
#  1.93092229 1.93007607 1.92923029 1.92790685 1.92764042 1.9266136
#  1.92529712 1.92139192 1.92120103 1.91545957 1.91521426 1.91514085
#  1.91461404 1.90554143 1.90350004 1.89683831 1.8953436  1.89260227
#  1.89064336 1.89031744 1.8902081  1.88660859 1.88572354 1.88374944
#  1.88231547 1.88173167 1.87882602 1.87870466 1.87380457 1.87302555
#  1.86196782 1.85958964 1.8583733  1.856878   1.8540153  1.85000621
#  1.83688746 1.8345538  1.79992278 1.73542389 1.69975088 1.69494519]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 4, iteration: 9, seed: 246042
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 30000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.74
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.76
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.79
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 15500
# serial calc_performance called
# Episode 15500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 16000
# serial calc_performance called
# Episode 16000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 16500
# serial calc_performance called
# Episode 16500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 17000
# serial calc_performance called
# Episode 17000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 17500
# serial calc_performance called
# Episode 17500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 18000
# serial calc_performance called
# Episode 18000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 18500
# serial calc_performance called
# Episode 18500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 19000
# serial calc_performance called
# Episode 19000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 19500
# serial calc_performance called
# Episode 19500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 20000
# serial calc_performance called
# Episode 20000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 20500
# serial calc_performance called
# Episode 20500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 21000
# serial calc_performance called
# Episode 21000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 21500
# serial calc_performance called
# Episode 21500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 22000
# serial calc_performance called
# Episode 22000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 22500
# serial calc_performance called
# Episode 22500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 23000
# serial calc_performance called
# Episode 23000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 23500
# serial calc_performance called
# Episode 23500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 24000
# serial calc_performance called
# Episode 24000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 24500
# serial calc_performance called
# Episode 24500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 25000
# serial calc_performance called
# Episode 25000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 25500
# serial calc_performance called
# Episode 25500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 26000
# serial calc_performance called
# Episode 26000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 26500
# serial calc_performance called
# Episode 26500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 27000
# serial calc_performance called
# Episode 27000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 27500
# serial calc_performance called
# Episode 27500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 28000
# serial calc_performance called
# Episode 28000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 28500
# serial calc_performance called
# Episode 28500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 29000
# serial calc_performance called
# Episode 29000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 29500
# serial calc_performance called
# Episode 29500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 30000
# serial calc_performance called
# Episode 30000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# best Policy network found at episode 23000
# Training completed.
# Tuneset 1, Iteration 9: [1.86313086 1.85816498 1.8557026  1.85553841 1.85551305 1.8537302
#  1.85330139 1.85191806 1.84948577 1.849324   1.84793346 1.84473666
#  1.84391302 1.84351442 1.84350479 1.8409104  1.84074168 1.83995742
#  1.83795498 1.83779637 1.83737715 1.83682519 1.83589662 1.83573674
#  1.8357085  1.83454336 1.83317952 1.83313434 1.83255871 1.83223911
#  1.83198425 1.83167033 1.83090217 1.82997189 1.82986685 1.82975425
#  1.8283166  1.82830051 1.82805991 1.82693687 1.82641529 1.82496747
#  1.82473281 1.82339761 1.82220357 1.82194756 1.82042759 1.81978329
#  1.81690133 1.8160953  1.81534652 1.81512637 1.81488782 1.80487752
#  1.80318084 1.79321959 1.76186032 1.73992738 1.70304972 1.69758622]
# seed  best_score
# 6  830634    1.959034
# 0  951408    1.957918
# 8  113336    1.953371
# 4  139600    1.946939
# 1  994461    1.945082
# 5  336338    1.900210
# 3  316452    1.869359
# 7  715240    1.866368
# 9  246042    1.863131
# 2  753771    1.857723
