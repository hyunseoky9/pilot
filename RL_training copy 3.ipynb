# %% [markdown]
# # Choose reference portfolio return

# %%
from pprdyn1 import *
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import pickle
import numpy as np
import pandas as pd
from performance_eval import avgperformance

config = {'policytype': 0, 'num_episodes': 1000}
settings = {'settingID': 18, 'for_RL': 0}
env = pprdyn1(settings)
summary = avgperformance(env, config, collect_data=True)
# average return using value iteraiton policy for each timestep.
summary['portfolioreturn'].mean(axis=0)
# Recommendation: average of the average returns is about *1.85*. Use this value as R_ref.
# Out:
# policy type: value iteration
# Episode 1000 done
# MC log_negV = -6.590662
# Average reward over 1000 episodes: -9.3339, certrainty equivalent: 1.3673
# array([2.22334062, 2.01649829, 1.85343344, 1.77733091, 1.75704407,
#        1.76121069, 1.78069268, 1.76588749, 1.75929858, 1.75398583])

# %%
# PPO training script
from PPO import *
from call_paramset import call_paramset, call_env
import pandas as pd
import random
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

if __name__ == "__main__":
    paramid = 3 # test id = 4
    iteration_num = 10
    hyperparameterization_set_filename = './hyperparamsets/PPOhyperparamsets.csv'
    paramdflist = call_paramset(hyperparameterization_set_filename,paramid)
    tuneset = 1
    best_scores = []
    seeds = []
    for paramdf in paramdflist: 
        for iteration in range(iteration_num):
            print('-------------------------------------------------------\n--------------------------------------------------------')
            seed = paramdf['seed'] # make sure iteration_num matches with the number of seeds if seeds are specified
            if seed == 'random':
                seednum = random.randint(0,1000000)
            else:
                seednum = int(seed)
            os.environ["PYTHONHASHSEED"] = str(seednum)
            random.seed(seednum)
            np.random.seed(seednum)
            torch.manual_seed(seednum)
            # environment configuration
            env = call_env(paramdf)
            meta = {'paramid': paramid, 'iteration': iteration, 'seed': seednum}
            agent = PPO(env, paramdf,meta)
            _, scores = agent.train()
            best_scores.append(np.max(scores))
            seeds.append(seednum)
            

            print(f"Tuneset {tuneset}, Iteration {iteration}: {scores}")
        tuneset += 1
    seedsNscores = pd.DataFrame({'seed': seeds, 'best_score': best_scores})
    print(seedsNscores.sort_values(by='best_score', ascending=False))
# Out:
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 3, iteration: 0, seed: 537151
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 15000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.72
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.75
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.78
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.78
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# best Policy network found at episode 10500
# Training completed.
# Tuneset 1, Iteration 0: [1.8784672  1.86579352 1.85551884 1.85482738 1.84930651 1.84910781
#  1.84816698 1.84568303 1.84545448 1.84429577 1.84132719 1.84046139
#  1.83889221 1.83802707 1.83800952 1.83708705 1.83645004 1.83218594
#  1.83181506 1.8311373  1.8311011  1.83030629 1.82766499 1.81569071
#  1.81180884 1.78212223 1.78061722 1.75020937 1.72300837 1.70071096]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 3, iteration: 1, seed: 47216
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 15000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.72
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.76
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.79
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.79
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# best Policy network found at episode 8500
# Training completed.
# Tuneset 1, Iteration 1: [1.87289806 1.86799959 1.86460101 1.859763   1.85686703 1.85604588
#  1.8536015  1.85289382 1.85137796 1.84641261 1.84546268 1.84543458
#  1.84424445 1.84259911 1.83922457 1.83281169 1.82661354 1.82651835
#  1.81814339 1.81619836 1.81526756 1.81091404 1.8082312  1.80673632
#  1.80658285 1.80351986 1.79101549 1.78674214 1.75842528 1.71565697]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 3, iteration: 2, seed: 93737
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 15000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.71
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.74
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.79
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.80
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.80
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.81
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.87
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# best Policy network found at episode 14500
# Training completed.
# Tuneset 1, Iteration 2: [1.86603943 1.86549702 1.86267739 1.85901917 1.85836892 1.85671674
#  1.85578434 1.85406169 1.8506662  1.84889598 1.84799654 1.84797287
#  1.84332831 1.84262901 1.84171421 1.83866617 1.83794706 1.83555177
#  1.83244956 1.83132463 1.82604894 1.82210515 1.82192921 1.82181812
#  1.81293412 1.80296196 1.79704703 1.7868927  1.73970338 1.71191242]
# -------------------------------------------------------
# --------------------------------------------------------
# Using cpu device
# paramID: 3, iteration:
# Using cpu device
# paramID: 3, iteration: 9, seed: 718634
# env: pprdyn1
# device: cpu
# state size: 8, action size: 231
# actor: hidden num: 3, hidden size: [32, 64, 32]
# critic: hidden num: 2, hidden size: [256, 256]
# actor lr: 0.0005, actor lr decay rate: 1.0, actor min lr: -inf
# critic lr: 0.0003, critic lr decay rate: 1.0, critic min lr: -inf
# standardize: True
# gamma: 0.999, gae_lambda: 0.95
# advantage normalization: True
# KL stopping: True, target KL: 0.02
# c1: 0.5, c2: 0.001, entropy_loss_included: True, policy_clip: 0.2
# rollout length: 512, minibatch size: 64, n_epochs: 12
# evaluation interval: 500, performance sampleN: 1000, parallel testing: False, deterministic eval: False
# max steps: 10, episodenum: 15000
# Episode 500
# serial calc_performance called
# Episode 500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.70
# -----------------------------------
# Episode 1000
# serial calc_performance called
# Episode 1000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.74
# -----------------------------------
# Episode 1500
# serial calc_performance called
# Episode 1500, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.76
# -----------------------------------
# Episode 2000
# serial calc_performance called
# Episode 2000, Learning Rate: A0.0005/C0.0003 Avg Performance: 1.81
# -----------------------------------
# Episode 2500
# serial calc_performance called
# Episode 2500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 3000
# serial calc_performance called
# Episode 3000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.82
# -----------------------------------
# Episode 3500
# serial calc_performance called
# Episode 3500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 4000
# serial calc_performance called
# Episode 4000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 4500
# serial calc_performance called
# Episode 4500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.85
# -----------------------------------
# Episode 5000
# serial calc_performance called
# Episode 5000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.84
# -----------------------------------
# Episode 5500
# serial calc_performance called
# Episode 5500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 6000
# serial calc_performance called
# Episode 6000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.83
# -----------------------------------
# Episode 6500
# serial calc_performance called
# Episode 6500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 7000
# serial calc_performance called
# Episode 7000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 7500
# serial calc_performance called
# Episode 7500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.86
# -----------------------------------
# Episode 8000
# serial calc_performance called
# Episode 8000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 8500
# serial calc_performance called
# Episode 8500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 9000
# serial calc_performance called
# Episode 9000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 9500
# serial calc_performance called
# Episode 9500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 10000
# serial calc_performance called
# Episode 10000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 10500
# serial calc_performance called
# Episode 10500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 11000
# serial calc_performance called
# Episode 11000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 11500
# serial calc_performance called
# Episode 11500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 12000
# serial calc_performance called
# Episode 12000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.89
# -----------------------------------
# Episode 12500
# serial calc_performance called
# Episode 12500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 13000
# serial calc_performance called
# Episode 13000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 13500
# serial calc_performance called
# Episode 13500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# Episode 14000
# serial calc_performance called
# Episode 14000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.88
# -----------------------------------
# Episode 14500
# serial calc_performance called
# Episode 14500, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.91
# -----------------------------------
# Episode 15000
# serial calc_performance called
# Episode 15000, Learning Rate: A0.000167/C0.0001 Avg Performance: 1.90
# -----------------------------------
# best Policy network found at episode 14500
# Training completed.
# Tuneset 1, Iteration 9: [1.91336569 1.91094411 1.90527737 1.90158751 1.90048989 1.90015061
#  1.89687065 1.89532814 1.89052844 1.89047759 1.88757985 1.887363
#  1.88384826 1.8797986  1.87744867 1.87607983 1.86387444 1.86221292
#  1.85898892 1.85190718 1.8476227  1.84545677 1.84093075 1.83745774
#  1.82947812 1.82072983 1.81152724 1.76322433 1.73537231 1.69979269]
# seed  best_score
# 7  176220    1.926035
# 9  718634    1.913366
# 8   23038    1.903703
# 4  948997    1.900952
# 0  537151    1.878467
# 3  925352    1.872901
# 1   47216    1.872898
# 6  194920    1.869933
# 2   93737    1.866039
# 5  914386    1.838663
